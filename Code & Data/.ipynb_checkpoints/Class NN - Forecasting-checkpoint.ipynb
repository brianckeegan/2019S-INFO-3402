# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sb

import numpy as np
import pandas as pd

pd.options.display.max_columns = 200

import statsmodels.formula.api as smf
import statsmodels.api as sm

# %%
# Read in data
df = pd.read_excel('state_govt_tax_collections.xls',sheet_name=0,header=[1],thousands=',',na_values='X')

# Rename columns
df.rename(columns={'Unnamed: 0':'Year','Unnamed: 1':'Index','Unnamed: 2':'State','Unnamed: 3':'FY'},inplace=True)

# Drop useless columns
df.drop(['Index','FY'],axis=1,inplace=True)

# Extract the state name
df['State'] = df['State'].str.extract(r'([A-Z\s]{2})')

# Drop columns that have US totals and happened before 1950
df = df[(df['State'] != "US") & (df['Year'] > 1950)]

# Inspect
df.head()
# Out:
#    Year State  Total Taxes  Property Tax (T01)  Tot Sales & Gr Rec Tax  \
# 1  2017    AL     10418152            395930.0                 5247294
# 2  2017    AK      1189786            120805.0                  263120
# 3  2017    AZ     13888611            993615.0                 8539726
# 4  2017    AR      9516281           1137886.0                 4701868
# 5  2017    CA    155632088           2681872.0                47940362
#
#    Total Gen Sales Tax (T09)  Total Select Sales Tax  \
# 1                  2654883.0                 2592411
# 2                        NaN                  263120
# 3                  6566503.0                 1973223
# 4                  3384394.0                 1317474
# 5                 35357699.0                12582663
#
#    Alcoholic Beverage Tax (T10)  Amusement Tax (T11)  \
# 1                        217790                  0.0
# 2                         40097              10668.0
# ...

# %%
df.query('State == "CA"').set_index(['Year'])['Property Tax (T01)'].plot()
